# %% [markdown]
# ## Important Point
#
# In a data sets there are various features (f1, f2, f3, f4...)
#
# Step 1: Divide it into independent and dependent feature.
#         Dependent Feature is the output feature which we need to compute (forcast)
#
# Step 2: If we have only two features, we can draw a 2D graph and see the relationship between them.
#         If we have 3 features, then we can draw a 3D diagaram to see the relationship
#         If we have more than 3 features, it is not possible to draw diagram to see the relationship
#
# Univariant Analysis: When we have only 1 feature
#
# Bivarient Analysis: When we have 2 features [here we draw 2D diagram]
#
# ### In seaborn we have multiple plot
# #### 1. JoinPlot: Help us to do BiVarient Analysis
# #### 2. PairPlot: Multivariate Analysis
# #### 3. Univariate Analysis
#         i. HISTOGRAM --> displot
#         ii. Box Plot and Whisker Plot --> boxplot

# %% [raw]
# BOX AND WHISKER PLOT
# Box -> The Middle Region
# Whisker -> The two Tail Region
#
# Box:
# Left End: Q1
# Middle Line : Q2
# Righ End: Q3
#
# Integquartile Range(IQR): Q3 - Q1
# Lower Limit: Q1 - 1.5IQR
# Upper Limit: Q3 + 1.5IQR
#
# Whisker
# LeftMost Tail - The Least value which is greater than Lower Limit
# RightMost Tail - The greatest value which is less that Upper Limit
#
# Any value which is lying outside the upper and lower limit are Outliners and are shown as dots

# %%
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### tip - dependent Feature [Which is numneric]
#
# #### total_bill, sex, smoker ... - Independent Variable
#
# ### When dependent variable is numeric then it is REGRESSION PROBLEM

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### species - dependent Feature [Which is categorical]
#
# #### sepal_length, sepal_width, petal_lenght, petal_width - Independent Variable
#
# ### When dependent variable is categorical then it is CLASSIFER PROBLEM

# %% [markdown]
# ## Correlation [Application = Feature Selection; If two dependent feature are highly correlated, then we can use one instead of both]

# %% [markdown]
# Coorelation between two feature is possible only when both  are non - catogorical type

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.corr(method = "pearson") # Correlation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.corr(method="spearman")
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.678968  0.604791
# tip           0.678968  1.000000  0.468268
# size          0.604791  0.468268  1.000000

# %%
sns.heatmap(df.corr(method="spearman"))

# %% [markdown]
# ## Univariate Analysis (analysing one Attribute) = DISTPLOT (HISTOGRAM)

# %%
sns.distplot(df["total_bill"], kde = False, bins = 5)

# %%
sns.distplot(df["total_bill"], kde = True, bins = 100) # kde --> Kernal Density Estiimation (PDF)

# bins --> Number of Histogram

# Note: When kde is shown then y axis is probaility, whereas when kde is not shown the y axis is values

# %%
sns.boxplot(df["tip"])

# %%
sns.boxplot(data = df) # Dra box plot for all the numberic features

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### In classifer problem for univariate analysis [bivariate analysis] - num + category

# %%
iris["test"] = 0 # insert a column with all zero
sns.pairplot(data= iris, x_vars=["sepal_length"], y_vars=["test"], hue = "species", size=5)
iris.drop(["test"], axis = 1, inplace = True) # ais is 1 for columns

# %% [markdown]
# ## Bivriate Analysis [2 Attribute] --> JOINPLOT --> Scatter Plot

# %% [raw]
# tip --> Dependent
# total bill --> Independent
# We Shall use joinplot

# %%
sns.jointplot(x = "total_bill", y = "tip", data=df)
# Scanner Diagram, with frequency histograme

# %%
sns.jointplot(x = "total_bill", y = "tip", data=df, kind = "reg") 
# It shall also add a regression line and probaility density function

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df, kind = "kde")
# kde stands for Krnel Density Estimate --> It is analogous to Histogram 
# and helps to undestand the concentartion of data

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df, kind = "hex")

# %% [markdown]
# ## MULTIVARIATE ANALYSIS (>2 ATTRIBUTE) --> PAIRPLOT
# Here we will make all possible pairs that is possible for attribute and plot them on graph

# %%
sns.pairplot(data = df)
# The pair of two same attribute leads two univariate analysis --> Histogram
# The pair of two different attribute forms bivariate analysis --> Scatter plot

# %% [markdown]
# ## HUE parameter
# In pair plot we have hue parameter -->
#
# Scatter Plot : it differntiate the poinnts by different color based on the attribute which is used in hue
#
# Histogram (kde) : It draws multiple kde for each diffrenet value in the attribute chosen in hue

# %%
sns.pairplot(data = df, hue = "day")
# Out:
# C:\Users\AdminUser\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\AdminUser\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
# df.loc[: , "day"].value_counts()
# series1 = df.loc[: , "day"] == "Thur"
# series2 = df.loc[: , "day"] == "Fri"
# series3 = df.loc[: , "day"] == "Sat"
# series4 = df.loc[: , "day"] == "Sun"

# df_thur = df.loc[series1, :]
# df_fri = df.loc[series2, :]
# df_sat = df.loc[series3, :]
# df_sun = df.loc[series4, :]

# %%
# import matplotlib.pyplot as plt
# plt.subplot(2,2,1)
# sns.distplot(df_thur["total_bill"], axlabel="thur", kde = False)
# plt.subplot(2,2,2)
# sns.distplot(df_fri["total_bill"], axlabel = "fri", kde = False)
# plt.subplot(2,2,3)
# sns.distplot(df_sat["total_bill"], axlabel = "sat", kde = False)
# plt.subplot(2,2,4)
# sns.distplot(df_sun["total_bill"], axlabel = "sun", kde = False)
# plt.show()

# %%
sns.jointplot(x = "sex", y = "total_bill")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-a863aa9884f0> in <module>
# ----> 1 sns.jointplot(x = "sex", y = "total_bill")
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2279
#    2280     # Initialize the JointGrid object
# -> 2281     grid = JointGrid(x, y, data, dropna=dropna,
#    2282                      height=height, ratio=ratio, space=space,
#    2283                      xlim=xlim, ylim=ylim)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size)
#    1700             if isinstance(var, str):
#    1701                 err = "Could not interpret input '{}'".format(var)
# -> 1702                 raise ValueError(err)
# ...

# %% [markdown]
# # CATEGORICAL DATA
#
# 1. UNIVARIATE : Countplot - Count the number of different category in feature ]
#                 PieChart
# 2. Bivariate (one categorical and one numeric) :
#
#     i. Bar Plot - mean of numeric value against each distinct data in categorical
#
#     ii. BOX PLOT
#
#     iii. Scatterplot

# %%
sns.countplot(df["sex"]) # Count the number of different category in feature

# %%
sns.barplot(x = df["day"], y = df["total_bill"]) # Plot the mean of Bill against the day

# %%
sns.boxplot(x = df["total_bill"], y = df["smoker"])

# %%
sns.boxplot(x = "day", y = "total_bill", data = df, hue = "sex")

# %%
#pie chart
plt.pie(x = values, labels  = lab )
